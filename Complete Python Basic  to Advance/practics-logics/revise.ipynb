# %%
a= 5
b=3 
print(a+b)
# Out:
# 8

# %%
c=a-b
print(c)
# Out:
# 2

# %%
# input from user
a = int(input("Enter first number: "))
print("You entered:", a)
# Out:
# You entered: 25

# %%
name = input("Enter your name: ")
print("Hello, " + name + "!")
# Out:
# Hello, ramesh!

# %%
print("This is a simple Python script that ' demonstrates basic arithmetic operations, user input, and string concatenation.")
# Out:
# This is a simple Python script that ' demonstrates basic arithmetic operations, user input, and string concatenation.

# %%
print(",what is your name hi   ")
# Out:
# ,what is your name hi

# %%
print("hi my name is ramesh \a how are you \a i am fine \a thank you \a")
# Out:
# hi my name is ramesh  how are you  i am fine  thank you

# %%
# \f: Form feed
print("This is a form feed character: \f, which moves the cursor to the next page.")
# Out:
# This is a form feed character: , which moves the cursor to the next page.

# %%
print(" hi i an riya \t how are you \t i am fine \t thank you \t")  # print a tab
# Out:
#  hi i an riya 	 how are you 	 i am fine 	 thank you

# %%
print("hi ramesh \O how are you \o i am fine \o thank you \o")  # print a backspace
# Out:
# hi ramesh \O how are you \o i am fine \o thank you \o

# %%
print("\x87 \x41 c\x42 i am fine \x43 thank you \x44")  # print a backspace
# Out:
#  A cB i am fine C thank you D

# %%
# row string
print(r"hi ramesh ")  # print a backspace
# Out:
# hi ramesh

# %%
print(r" hi my  name is ramesh and how are you")
# Out:
#  hi my  name is ramesh and how are you

# %%
text = "Hello\nWorld"
print(text)
# Out:
# Hello
# World

# %%
text = r"Hello\nWorld"
print(text)
# Out:
# Hello\nWorld

# %%
path = r"C:\new\test"
print(path)
# Out:
# C:\new\test

# %%
# create a variable :
num = 4 
flot_num = 4.5
print(num)
# Out:
# 4

# %%
print(num + flot_num)  # Output: 8.5
# Out:
# 8.5

# %%
# type of operators  :
# 1. Arithmetic operators
# 2. Comparison operators
# 3. Logical operators
# 4. Assignment operators
# 5. Bitwise operators
# 6. Membership operators
# 7. Identity operators
# 8. Unary operators

# now i  start 1  Arithmetic operators
a  = 10 
b= 20.
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b) 
print(a%b)
print(a**b)
# Out:
# 30.0
# -10.0
# 200.0
# 0.5
# 0.0
# 10.0
# 1e+20

# %%
# commparison operators: it is return boolean value True or False
a = 10
b = 20
print(a == b)  # False
# Out:
# False

# %%
print(a>b)
# Out:
# False

# %%
print(a< b)
# Out:
# True

# %%
print(a!=b)
# Out:
# True

# %%
print(a>=b)
# Out:
# False

# %%
print(a<=b)
# Out:
# True

# %%
print(a != b)  # True
# Out:
# True

# %%
# use bitwise operators: it is return boolean value True or False
a=10
b=150
print(a & b) # Bitwise AND
# Out:
# 2

# %%
print(a|b )
# Out:
# 158

# %%
print(a^b) # Bitwise XOR
# Out:
# 156

# %%
print(~a) # Bitwise NOT
# Out:
# -11

# %%
print(~b)
# Out:
# -151

# %%
# logical operators: it is return boolean value True or False
x = True
y = False
print(x and y) # Logical AND
# Out:
# False

# %%
print(x or y) # Logical OR
# Out:
# True

# %%
print(not x) # Logical NOT
# Out:
# False

# %%
# memmbership operators: it is return boolean value True or False
list1 = [1, 2, 3, 4, 5]
print(2 in list1)
# Out:
# True

# %%
print(1 not in list1)
# Out:
# False

# %%
# identity operators: it is return boolean value True or False
a=10 
b= 20
print(a is b)
# Out:
# False

# %%
print(a is not b)
# Out:
# True

# %%
# unary operators: it is return boolean value True or False
a=10 
b=20
print(+a)  # Unary plus
# Out:
# 10

# %%
print(+b)
# Out:
# 20

# %%
print(-a)
# Out:
# -10

# %%
# shift operators: it is return boolean value True or False
a= 10 
b= 20 
print(a << b)
# Out:
# 10485760

# %%
print(a >> b )
# Out:
# 0

# %%
# * operator:
name = " ramesh "
a=5
print(name * a)  # Output: "
# Out:
#  ramesh  ramesh  ramesh  ramesh  ramesh

# %%
# name = "jon"
# sir_name= " kumar "
# print(name * sir_name) # it will throw an errore becouse  it is not allowed  to multiply  string with string

# %%
# name = " neha "
# a= 2.32
# print(name * a)  # Output: " it will throw an error because it is not allowed to multiply a string with a float

# %%
# type conversion: it is return boolean value True or False
# it is two  types of type conversion:  1- implicit type conversion  2- explicit type conversion
# 1- implicit type conversion: it is automatically convert one data type to another data type
# 2- explicit type conversion: it is manually convert one data type to another data type
# 1- Example of implicit type conversion:
a= 6 
b= 2.5
c=32
d= 214.2
result = a+b
print(result )
# Out:
# 8.5

# %%
print(a-b)
# Out:
# 3.5

# %%
print(a*b)
# Out:
# 15.0

# %%
# 2- explicit type conversion: it is manually convert one data type to another data type
a= 10
b= 2.5
c= str(a)  
d= int(b) 
print(c)
print(d)
# Out:
# 10
# 2

# %%
print(str(a) +  str(b))
# Out:
# 102.5

# %%
print(str(a-b))
# Out:
# 7.5

# %%
print(float(a*b))
# Out:
# 25.0

# %%
# types of mutable and immutable data types in python:
# mutable: list, dict, set , bytearray
# immutable: int, float, str, tuple, frozenset,boolean,complex

# now start with mutable data types :
list1 = [1, 2, 3, 4, 5]
print(list1)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(list1[0])
# Out:
# 1

# %%
list1[0] = 10

# %%
print(list1)
# Out:
# [10, 2, 3, 4, 5]

# %%
list1[2]=40

# %%
print(list1)
# Out:
# [10, 2, 40, 4, 5]

# %%
# dictionary
dict1 = {"a": 1, "b": 2, "c": 3}
print(dict1)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
dict1["a"]=1100000

# %%
print(type(dict1))
# Out:
# <class 'dict'>

# %%
student = {
    "name": "Ramesh",
    "age": 22
}

student["age"] = 23

print(student)
# Out:
# {'name': 'Ramesh', 'age': 23}

# %%
print(type(student))
# Out:
# <class 'dict'>

# %%
student["age"] = 50

# %%
print(student  )
# Out:
# {'name': 'Ramesh', 'age': 50}

# %%
# set: it is a collection of unique elements and it is mutable
set1 = {1, 2, 3, 4, 5}
print(set1)
# Out:
# {1, 2, 3, 4, 5}

# %%
set1.add(6)
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1 = {1, 2, 3, 4, 5,6,6,4,5} # a set with unique elements
print(set1)
set1.remove(3)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
print(set1)
# Out:
# {1, 2, 4, 5, 6}

# %%
list1 = [1, 2, 3, 4, 5]
list1[2] = 25
print(list1)
# Out:
# [1, 2, 25, 4, 5]

# %%
# name = "Ramesh"

# name[0] = "S" # it will throw an error because string is immutable

# %%
# bytearry:
data = bytearray([10, 20, 30])

print(data)

data[0] = 100

print(data)
# Out:
# bytearray(b'\n\x14\x1e')
# bytearray(b'd\x14\x1e')

# %%
print(data)
# Out:
# bytearray(b'd\x14\x1e')

# %%
# number:
a= 123.3
a
# Out:
# 123.3

# %%
# complex number:
a = 2 + 3j
a
# Out:
# (2+3j)

# %%
b= 2+4j+2
b
# Out:
# (4+4j)

# %%
c= 1+2j+8
c
# Out:
# (9+2j)

# %%
# what is range in python: range is a built-in function that returns a sequence of numbers, starting from 0 by default, and increments by 1 (by default), and stops before a specified number. It is commonly used in for loops to iterate over a sequence of numbers
for i in range(5):
    r=i
    print(r)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
 # Decision control :
