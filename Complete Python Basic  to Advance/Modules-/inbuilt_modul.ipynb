# %%
import calendar as cs

# %%
import sys

print(sys.version)
# Out:
# 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]

# %%
import math

print(math.sqrt(25))
# Out:
# 5.0

# %%
import random

# %%
num = random.randint(1,212)

# %%
print(num )
# Out:
# 169

# %%
import os

print(os.listdir())
# Out:
# ['calculator.py', 'calculator1.py', 'inbuilt_modul.ipynb', 'main.py', '__pycache__']

# %%
import datetime

# %%
now = datetime.datetime.now()
print(now)
# Out:
# 2026-09-20 16:49:35.297819
